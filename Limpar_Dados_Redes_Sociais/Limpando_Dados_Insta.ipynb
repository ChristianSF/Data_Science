# %%
import pandas as pd

# %%
dados = pd.read_csv("/content/agosto.csv")

# %%
dados.head()
# Out:
#               Data         ID do post  ... Saídas da story (Instagram) Etiquetas
# 0   3/8/2020 19:41  18064518421232946  ...                         NaN       NaN
# 1   6/8/2020 19:33  18044897035258738  ...                         NaN       NaN
# 2   9/8/2020 14:31  17917835827444245  ...                         NaN       NaN
# 3  12/8/2020 19:13  18074893636209963  ...                         NaN       NaN
# 4  15/8/2020 19:11  18100501144194804  ...                         NaN       NaN
#
# [5 rows x 21 columns]

# %%
dados.columns
# Out:
# Index(['Data', 'Tipo de post', 'Nome', 'Link', 'Post', 'Conteúdo vinculado',
#        'Impressões (Instagram)', 'Alcance (Instagram)',
#        'Taxa de engajamento (por impressão) (Instagram)',
#        'Engajamentos (Instagram)', 'Curtidas (Instagram)',
#        'Comentários (Instagram)', 'Salvos (Instagram)',
#        'Visualizações de posts de vídeo (Instagram)',
#        'Respostas à story (Instagram)',
#        'Toques na story para voltar (Instagram)',
#        'Toques na story para avançar (Instagram)',
#        'Saídas da story (Instagram)', 'Etiquetas'],
#       dtype='object')

# %%
dados = dados.drop(columns=['Enviado por'])

# %%
dados = dados.drop(columns=['ID do post'])

# %%
dados = dados.drop(columns=['Conteúdo vinculado'])

# %%
dados = dados.drop(columns=['Visualizações de posts de vídeo (Instagram)'])

# %%
dados = dados.drop(columns=['Respostas à story (Instagram)'])

# %%
dados = dados.drop(columns=['Toques na story para voltar (Instagram)'])

# %%
dados = dados.drop(columns=['Toques na story para avançar (Instagram)'])

# %%
dados = dados.drop(columns=['Saídas da story (Instagram)'])

# %%
dados = dados.drop(columns=['Etiquetas'])

# %%
dados.columns
# Out:
# Index(['Data', 'Tipo de post', 'Nome', 'Link', 'Post',
#        'Impressões (Instagram)', 'Alcance (Instagram)',
#        'Taxa de engajamento (por impressão) (Instagram)',
#        'Engajamentos (Instagram)', 'Curtidas (Instagram)',
#        'Comentários (Instagram)', 'Salvos (Instagram)'],
#       dtype='object')

# %%
dados.columns = ['Data', 'Tipo', 'Nome', 'Link', 'Descrição', 'Impressões', 'Alcance', 'Taxa de Engajamento (Por Impressões)', 'Engajamentos', 'Curtidas', 'Comentários', 'Salvo']

# %%
dados.shape
# Out:
# (9, 12)

# %%
dados.head()
# Out:
#               Data                           Tipo  ... Comentários Salvo
# 0   3/8/2020 19:41  Post do Instagram (Carrossel)  ...           2    10
# 1   6/8/2020 19:33  Post do Instagram (Carrossel)  ...          27    17
# 2   9/8/2020 14:31  Post do Instagram (Carrossel)  ...           5    53
# 3  12/8/2020 19:13       Post do Instagram (Foto)  ...          59    18
# 4  15/8/2020 19:11       Post do Instagram (Foto)  ...           3     6
#
# [5 rows x 12 columns]

# %%
dados.to_excel("dados_insta_agosto.xlsx", header=True)
